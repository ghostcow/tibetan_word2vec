# %%
import os
import re

# %%
for root,folders,files in os.walk('../data/clean'):
    if len(files) > 0:
        print(files[0])
# Out:
# TD4330E.txt
# TD4016.3E.txt
# TD4018E.txt
# TD3988E.txt
# TD4010E.txt
# TD3994E.txt
# TD4016.1E.txt
# TD3995E.txt
# TD4019E.txt
# TD4002E.txt
# TD4016.2E.txt
# TD1153E.txt
# TD1198E.txt
# TD1844E.txt
# TD3149E.txt
# TD1932E.txt
# TD1190E.txt
# TD1793.1E.txt
# TD1653E.txt
# TD2200E.txt
# TD1255E.txt
# TD1395E.txt
# TD3709E.txt
# TD2321E.txt
# TD1418E.txt
# TD1419E.txt
# TD3758E.txt
# TD2512.2E.txt
# TD1788E.txt
# TD1401E.txt
# TD3296E.txt
# TD1798E.txt
# TD1347.2E.txt
# TD2627E.txt
# TD2014E.txt
# TD1412E.txt
# TD1194E.txt
# TD2546E.txt
# TD1908E.txt
# TD1574E.txt
# TD2450E.txt
# TD2691E.txt
# TD1352E.txt
# TD2503.1E.txt
# TD3327E.txt
# TD1841E.txt
# TD1614E.txt
# TD1516E.txt
# TD2615E.txt
# TD1323E.txt
# TD2662E.txt
# TD2140E.txt
# TD2889E.txt
# TD1188E.txt
# TD1215E.txt
# TD2511E.txt
# TD1863E.txt
# TD1182E.txt
# TD2510.1E.txt
# TD1704E.txt
# TD1374E.txt
# TD2504E.txt
# TD1786E.txt
# TD2514E.txt
# TD2683E.txt
# TD2245E.txt
# TD1346E.txt
# TD1851.2E.txt
# TD1784E.txt
# TD1872E.txt
# ...
